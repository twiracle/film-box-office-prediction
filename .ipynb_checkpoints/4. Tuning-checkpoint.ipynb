# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_log_error
from lightgbm import LGBMRegressor
import lightgbm as lgbm
from lightgbm import early_stopping

import optuna
from typing import Callable
from tqdm import tqdm
import joblib
import warnings

warnings.filterwarnings("ignore")

RAND = 42
N_FOLDS = 5

# %% [markdown]
# # Описание и импорт данных

# %% [markdown]
# Задачей данного проекта является предсказание кассовых сборов фильмов.
# Данные были собраны с сайта Кинопоиск с использованием собственного парсера. Были выбраны данные о фильмах США за все годы с первых 1000 страниц сайта (на следующих страницах информации о кассовых сборах практически не было).

# %% [markdown]
# Проект был разделен на несколько частей, каждая из которых представляет собой отдельный Jupyter ноутбук:
# 1. Parsing-Kinopoisk – сбор и данных для дальнейшего анализа
# 2. EDA – исследовательский анализ данных, который включает в себя первичный анализ данных, обработку пропусков, преобразование признаков выявление закономерностей и взаимосвязей в данных, формулировка гипотез и визуализация наиболее важных признаков
# 3. Baseline – обучение baseline модели и оценка ее метрик
# 4. **Tuning – подбор гиперпараметров модели для улучшения качества предсказаний и оценка полученных метрик**
# 5. Post-analysis – оценка важности признаков и анализ результатов предсказания

# %% [markdown]
# **Описания полей:**
# - rating - пользовательский рейтинг на Кинопоиске
# - production_year - год производства
# - director - режиссер
# - age_rating - возрастной рейтинг
# - duration - продолжительность в минутах
# - budget - бюджет фильма
# - **target - кассовые сборы фильма**
# - target_log - прологарифмированное значение target (распределение более близкое к нормальному)
# - main_genre - основной жанр фильма
# - month - месяц выпуска фильма
# - director_film_count - количество фильмов, которые снял режиссер
# - actors_fame - слава актеров, которые снимались в фильме (слава = количество фильмов, в которых снимались актеры)

# %%
df = pd.read_csv('data/df_clean.csv')

# %%
df.head()
# Out:
#    rating  production_year         director age_rating  duration       budget  \
# 0     8.6             2019         Гай Ричи        18+       113   22000000.0
# 1     8.0             2013  Мартин Скорсезе        18+       180  100000000.0
# 2     8.3             1990    Крис Коламбус         0+       103   18000000.0
# 3     8.1             2019    Райан Джонсон        18+       130   40000000.0
# 4     8.5             2018            Other        18+       130   23000000.0
#
#         target  target_log main_genre     month  director_film_count  \
# 0  115171795.0   18.561935   криминал   декабрь                    5
# 1  392000694.0   19.786774      драма   декабрь                   26
# 2  476684675.0   19.982366    комедия    ноябрь                   12
# 3  312897920.0   19.561388   детектив  сентябрь                    6
# 4  321752656.0   19.589294  биография  сентябрь                    1
#
#    actors_fame
# 0           46
# 1           54
# 2           39
# 3           40
# 4           25

# %% [markdown]
# # Подготовка данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11586 entries, 0 to 11585
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rating               11586 non-null  float64
#  1   production_year      11586 non-null  int64
#  2   director             11586 non-null  object
#  3   age_rating           11586 non-null  object
#  4   duration             11586 non-null  int64
#  5   budget               11586 non-null  float64
#  6   target               11586 non-null  float64
#  7   target_log           11586 non-null  float64
#  8   main_genre           11586 non-null  object
#  9   month                11586 non-null  object
#  10  director_film_count  11586 non-null  int64
#  11  actors_fame          11586 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# - как видим, пропущенных значений в данных нет (они были обработаны на предыдущем этапе) и у всех переменных правильные типы данных
# - так как в данном проекте используется CatBoost, то все признаки типа object нужно перевести в тип category, что избавит нас от бинаризации категориальных признаков
# - вместо target при обучении мы будем использовать target_log, так как у этой переменной более нормальное распределение

# %%
# выбор признаков с типом данных 'object'
cols_to_cat = [col for col in df.columns if df[col].dtype == 'object']

# %%
# изменение типа данных на 'category'
df[cols_to_cat] = df[cols_to_cat].astype('category')

# %% [markdown]
# - разделим данные на X и y

# %%
X = df.drop(['target', 'target_log'], axis=1)
y = df.target_log

# %% [markdown]
# - разделим данные на train, validation и test в соотношении 64%/16%/20%

# %%
# разделение на train и test
X_train_, X_test, y_train_, y_test = train_test_split(X,
                                                      y,
                                                      test_size=0.2,
                                                      shuffle=True,
                                                      random_state=RAND)

# разделение на train и validation
X_train, X_val, y_train, y_val = train_test_split(X_train_,
                                                  y_train_,
                                                  test_size=0.16,
                                                  shuffle=True,
                                                  random_state=RAND)

# %% [markdown]
# # Подбор параметров

# %% [markdown]
# По результатам предыдущего ноутбука было решено использовать **LightGBM**  и для нее подбирать параметры. В качестве метрики для оценки была выбрана **MAE**, так как она более устойчива к выбросам.
#
# Основные параметры модели:
# - n_estimators - максимальное количество деревьев
# - learning_rate - скорость обучения
# - num_leaves - максимальное количество листьев в дереве
# - max_depth - максимальная глубина деревьев
# - max_bin - максимальное количество бинов, на которые будут разбиты target значения
# - min_data_in_leaf - минимальное количество данных в листе
# - bagging_fraction - процент выборок, которые будут использоваться для обучения каждого дерева
# - bagging_freq - каждые k итераций нужно выполнять bagging
# - lambda_l1 - l1 регуляризация
# - lambda_l2 - l2 регуляризация
# - min_split_gain - минимальное снижение потерь, необходимое для дальнейшего разбиения на листы

# %%
# выбор категориальных признаков
cat_features = list(X_train.select_dtypes('category').columns)

# %% [markdown]
# - попробуем подобрать параметры для модели, чтобы улушить ее результаты

# %%
# целевая функция
def objective_lgb(trial, X_train: np.ndarray, y_train: np.ndarray,
                  X_val: np.ndarray, y_val: np.ndarray, random_state: int,
                  cat_features: list):
    '''
    Функция для подбора параметров с помощью optuna
    
    Parameters
    ------------
    trial
        текущая попытка подбора
    X_train: np.ndarray
        тренировочные значения X
    y_train: np.ndarray
        тренировочные значения y
    X_val: np.ndarray
        валидационные значения X
    y_val: np.ndarray
        валидационные значения y
    random_state: int
    cat_features: list
        список с категориальными переменными в наборе
    
    Returns
    -----------
    MAE на текущем trial
    '''
    lgb_params = {
        "n_estimators":
        trial.suggest_categorical("n_estimators", [857]),
        #         trial.suggest_int("n_estimators", 300, 1000),
        "learning_rate":
        trial.suggest_categorical("learning_rate", [0.045309611206922125]),
        #                 trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
        "num_leaves":
        trial.suggest_int("num_leaves", 20, 100),
        "max_depth":
        trial.suggest_int("max_depth", 3, 9),
        "max_bin":
        trial.suggest_int("max_bin", 50, 500),
        "min_data_in_leaf":
        trial.suggest_int("min_data_in_leaf", 30, 150),
        "bagging_fraction":
        trial.suggest_float("bagging_fraction", 0.5, 1),
        "bagging_freq":
        trial.suggest_int("bagging_freq", 1, 5),
        "lambda_l1":
        trial.suggest_int("lambda_l1", 0, 20),
        "lambda_l2":
        trial.suggest_int("lambda_l2", 0, 20),
        "min_split_gain":
        trial.suggest_int("min_split_gain", 0, 20),
        "colsample_bytree":
        trial.suggest_float("colsample_bytree", 0.2, 1.0),
        'objective':
        trial.suggest_categorical("objective", ['mae']),
        'verbosity':
        trial.suggest_categorical("verbosity", [-1]),
        "random_state":
        trial.suggest_categorical("random_state", [random_state])
    }

    model = LGBMRegressor(**lgb_params)
    model.fit(X_train,
              y_train,
              eval_set=[(X_val, y_val)],
              eval_metric="mae",
              categorical_feature=cat_features,
              callbacks=[early_stopping(stopping_rounds=100)])

    y_pred = model.predict(X_val)

    return mean_absolute_error(np.exp(y_val), np.exp(y_pred))

# %%
# создание study и подбор параметров
study_lgbm = optuna.create_study(direction="minimize", study_name="lgbm")
func = lambda trial: objective_lgb(trial,
                                   X_train,
                                   y_train,
                                   X_val,
                                   y_val,
                                   random_state=RAND,
                                   cat_features=cat_features)
study_lgbm.optimize(func, n_trials=100, show_progress_bar=True)
# Out:
# [I 2024-10-24 16:01:20,742] A new study created in memory with name: lgbm
#   0%|          | 0/100 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [95]	valid_0's l1: 1.63748
# [I 2024-10-24 16:01:20,912] Trial 0 finished with value: 30201333.880960457 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 47, 'max_depth': 9, 'max_bin': 397, 'min_data_in_leaf': 40, 'bagging_fraction': 0.646883907558091, 'bagging_freq': 4, 'lambda_l1': 16, 'lambda_l2': 3, 'min_split_gain': 19, 'colsample_bytree': 0.6758316885737955, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 0 with value: 30201333.880960457.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [280]	valid_0's l1: 1.60988
# [I 2024-10-24 16:01:21,032] Trial 1 finished with value: 30473458.99333793 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 86, 'max_depth': 8, 'max_bin': 461, 'min_data_in_leaf': 104, 'bagging_fraction': 0.5411278952659002, 'bagging_freq': 4, 'lambda_l1': 5, 'lambda_l2': 17, 'min_split_gain': 9, 'colsample_bytree': 0.4150570779761907, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 0 with value: 30201333.880960457.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [538]	valid_0's l1: 1.62154
# [I 2024-10-24 16:01:21,199] Trial 2 finished with value: 30691293.672163714 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 78, 'max_depth': 3, 'max_bin': 152, 'min_data_in_leaf': 121, 'bagging_fraction': 0.8515068420609943, 'bagging_freq': 1, 'lambda_l1': 5, 'lambda_l2': 4, 'min_split_gain': 17, 'colsample_bytree': 0.967322150430592, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 0 with value: 30201333.880960457.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [442]	valid_0's l1: 1.6432
# [I 2024-10-24 16:01:21,332] Trial 3 finished with value: 31240379.81804996 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 25, 'max_depth': 7, 'max_bin': 122, 'min_data_in_leaf': 51, 'bagging_fraction': 0.7518400160075311, 'bagging_freq': 4, 'lambda_l1': 16, 'lambda_l2': 0, 'min_split_gain': 11, 'colsample_bytree': 0.22964304914723252, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 0 with value: 30201333.880960457.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [103]	valid_0's l1: 1.6569
# [I 2024-10-24 16:01:21,417] Trial 4 finished with value: 29959399.39186418 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 67, 'max_depth': 3, 'max_bin': 385, 'min_data_in_leaf': 121, 'bagging_fraction': 0.9318422082345181, 'bagging_freq': 3, 'lambda_l1': 2, 'lambda_l2': 0, 'min_split_gain': 20, 'colsample_bytree': 0.8864372788943764, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 29959399.39186418.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [845]	valid_0's l1: 1.42746
# [I 2024-10-24 16:01:21,809] Trial 5 finished with value: 29875750.13121866 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 79, 'max_depth': 8, 'max_bin': 343, 'min_data_in_leaf': 104, 'bagging_fraction': 0.5357002849272381, 'bagging_freq': 3, 'lambda_l1': 1, 'lambda_l2': 7, 'min_split_gain': 2, 'colsample_bytree': 0.685308952175685, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 5 with value: 29875750.13121866.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [138]	valid_0's l1: 1.48631
# [I 2024-10-24 16:01:21,938] Trial 6 finished with value: 28636001.620889675 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 37, 'max_depth': 7, 'max_bin': 287, 'min_data_in_leaf': 125, 'bagging_fraction': 0.9505103160172099, 'bagging_freq': 3, 'lambda_l1': 0, 'lambda_l2': 16, 'min_split_gain': 7, 'colsample_bytree': 0.5992132814167417, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l1: 1.59912
# [I 2024-10-24 16:01:22,013] Trial 7 finished with value: 29581840.802728407 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 70, 'max_depth': 8, 'max_bin': 337, 'min_data_in_leaf': 148, 'bagging_fraction': 0.6526223538915255, 'bagging_freq': 3, 'lambda_l1': 1, 'lambda_l2': 4, 'min_split_gain': 13, 'colsample_bytree': 0.8166538048165595, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [100]	valid_0's l1: 1.61324
# [I 2024-10-24 16:01:22,099] Trial 8 finished with value: 29321858.13790734 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 99, 'max_depth': 4, 'max_bin': 485, 'min_data_in_leaf': 107, 'bagging_fraction': 0.8963400433703949, 'bagging_freq': 2, 'lambda_l1': 16, 'lambda_l2': 1, 'min_split_gain': 16, 'colsample_bytree': 0.8951951974237522, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [124]	valid_0's l1: 1.59039
# [I 2024-10-24 16:01:22,176] Trial 9 finished with value: 29556638.26964125 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 83, 'max_depth': 9, 'max_bin': 197, 'min_data_in_leaf': 71, 'bagging_fraction': 0.6901930242731549, 'bagging_freq': 2, 'lambda_l1': 12, 'lambda_l2': 2, 'min_split_gain': 19, 'colsample_bytree': 0.5452646039574047, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [326]	valid_0's l1: 1.5316
# [I 2024-10-24 16:01:22,379] Trial 10 finished with value: 30174923.77271576 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 45, 'max_depth': 5, 'max_bin': 244, 'min_data_in_leaf': 144, 'bagging_fraction': 0.9931523889986794, 'bagging_freq': 5, 'lambda_l1': 9, 'lambda_l2': 16, 'min_split_gain': 5, 'colsample_bytree': 0.42306958791237953, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [694]	valid_0's l1: 1.54568
# [I 2024-10-24 16:01:22,669] Trial 11 finished with value: 28903279.256545026 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 100, 'max_depth': 5, 'max_bin': 53, 'min_data_in_leaf': 88, 'bagging_fraction': 0.8631650213732266, 'bagging_freq': 1, 'lambda_l1': 19, 'lambda_l2': 12, 'min_split_gain': 7, 'colsample_bytree': 0.7597152333766188, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [443]	valid_0's l1: 1.53405
# [I 2024-10-24 16:01:22,871] Trial 12 finished with value: 28809946.565074198 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 21, 'max_depth': 6, 'max_bin': 66, 'min_data_in_leaf': 77, 'bagging_fraction': 0.8063433812718004, 'bagging_freq': 1, 'lambda_l1': 19, 'lambda_l2': 13, 'min_split_gain': 6, 'colsample_bytree': 0.7558169793399777, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 6 with value: 28636001.620889675.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [821]	valid_0's l1: 1.3985
# [I 2024-10-24 16:01:23,330] Trial 13 finished with value: 27827470.649309915 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 21, 'max_depth': 6, 'max_bin': 269, 'min_data_in_leaf': 70, 'bagging_fraction': 0.8034593695129856, 'bagging_freq': 2, 'lambda_l1': 9, 'lambda_l2': 20, 'min_split_gain': 1, 'colsample_bytree': 0.5534718059962365, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 13 with value: 27827470.649309915.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [821]	valid_0's l1: 1.38257
# [I 2024-10-24 16:01:24,095] Trial 14 finished with value: 28004827.41672821 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 35, 'max_depth': 6, 'max_bin': 274, 'min_data_in_leaf': 61, 'bagging_fraction': 0.9960733524993097, 'bagging_freq': 2, 'lambda_l1': 9, 'lambda_l2': 20, 'min_split_gain': 0, 'colsample_bytree': 0.5381067979310976, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 13 with value: 27827470.649309915.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [857]	valid_0's l1: 1.38492
# [I 2024-10-24 16:01:24,843] Trial 15 finished with value: 27621185.47923853 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 34, 'max_depth': 6, 'max_bin': 248, 'min_data_in_leaf': 60, 'bagging_fraction': 0.7690085115507808, 'bagging_freq': 2, 'lambda_l1': 10, 'lambda_l2': 19, 'min_split_gain': 0, 'colsample_bytree': 0.4731449955726449, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [568]	valid_0's l1: 1.4878
# [I 2024-10-24 16:01:25,162] Trial 16 finished with value: 28807444.395756952 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 30, 'max_depth': 5, 'max_bin': 225, 'min_data_in_leaf': 33, 'bagging_fraction': 0.7647441310259863, 'bagging_freq': 2, 'lambda_l1': 12, 'lambda_l2': 20, 'min_split_gain': 2, 'colsample_bytree': 0.399360689564225, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [836]	valid_0's l1: 1.3984
# [I 2024-10-24 16:01:26,104] Trial 17 finished with value: 28416486.712844055 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 52, 'max_depth': 7, 'max_bin': 189, 'min_data_in_leaf': 54, 'bagging_fraction': 0.7043172070529465, 'bagging_freq': 2, 'lambda_l1': 7, 'lambda_l2': 9, 'min_split_gain': 0, 'colsample_bytree': 0.2798390484439238, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [856]	valid_0's l1: 1.47756
# [I 2024-10-24 16:01:26,404] Trial 18 finished with value: 29290856.43867717 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 40, 'max_depth': 4, 'max_bin': 298, 'min_data_in_leaf': 79, 'bagging_fraction': 0.8061112490804565, 'bagging_freq': 1, 'lambda_l1': 12, 'lambda_l2': 18, 'min_split_gain': 3, 'colsample_bytree': 0.4692220231809719, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [374]	valid_0's l1: 1.49446
# [I 2024-10-24 16:01:26,708] Trial 19 finished with value: 29944818.452114884 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 20, 'max_depth': 6, 'max_bin': 144, 'min_data_in_leaf': 66, 'bagging_fraction': 0.6051645191037271, 'bagging_freq': 2, 'lambda_l1': 6, 'lambda_l2': 14, 'min_split_gain': 4, 'colsample_bytree': 0.32251698190801287, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [852]	valid_0's l1: 1.39981
# [I 2024-10-24 16:01:27,374] Trial 20 finished with value: 28624379.884407677 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 56, 'max_depth': 4, 'max_bin': 347, 'min_data_in_leaf': 45, 'bagging_fraction': 0.8024031585305422, 'bagging_freq': 5, 'lambda_l1': 14, 'lambda_l2': 19, 'min_split_gain': 0, 'colsample_bytree': 0.5162812396225498, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [854]	valid_0's l1: 1.38276
# [I 2024-10-24 16:01:28,238] Trial 21 finished with value: 28032149.042752814 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 30, 'max_depth': 6, 'max_bin': 257, 'min_data_in_leaf': 63, 'bagging_fraction': 0.9886222314233157, 'bagging_freq': 2, 'lambda_l1': 9, 'lambda_l2': 20, 'min_split_gain': 0, 'colsample_bytree': 0.5988722447243054, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [359]	valid_0's l1: 1.41247
# [I 2024-10-24 16:01:28,521] Trial 22 finished with value: 27646126.751457453 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 34, 'max_depth': 7, 'max_bin': 303, 'min_data_in_leaf': 58, 'bagging_fraction': 0.8600738555601717, 'bagging_freq': 2, 'lambda_l1': 8, 'lambda_l2': 15, 'min_split_gain': 2, 'colsample_bytree': 0.508119768307825, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [838]	valid_0's l1: 1.43311
# [I 2024-10-24 16:01:28,846] Trial 23 finished with value: 28688748.363106366 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 29, 'max_depth': 7, 'max_bin': 307, 'min_data_in_leaf': 82, 'bagging_fraction': 0.8551174567788484, 'bagging_freq': 1, 'lambda_l1': 8, 'lambda_l2': 15, 'min_split_gain': 2, 'colsample_bytree': 0.3481625881035958, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [233]	valid_0's l1: 1.48493
# [I 2024-10-24 16:01:29,039] Trial 24 finished with value: 28252871.36151458 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 43, 'max_depth': 5, 'max_bin': 220, 'min_data_in_leaf': 55, 'bagging_fraction': 0.7227202514397844, 'bagging_freq': 2, 'lambda_l1': 11, 'lambda_l2': 11, 'min_split_gain': 4, 'colsample_bytree': 0.4833704672563334, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [249]	valid_0's l1: 1.42808
# [I 2024-10-24 16:01:29,286] Trial 25 finished with value: 27883936.64265227 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 33, 'max_depth': 6, 'max_bin': 380, 'min_data_in_leaf': 90, 'bagging_fraction': 0.7859175593102783, 'bagging_freq': 3, 'lambda_l1': 4, 'lambda_l2': 18, 'min_split_gain': 2, 'colsample_bytree': 0.6593959575064885, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [120]	valid_0's l1: 1.51746
# [I 2024-10-24 16:01:29,440] Trial 26 finished with value: 28848191.964814477 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 25, 'max_depth': 7, 'max_bin': 431, 'min_data_in_leaf': 34, 'bagging_fraction': 0.8954385388668051, 'bagging_freq': 2, 'lambda_l1': 10, 'lambda_l2': 18, 'min_split_gain': 10, 'colsample_bytree': 0.5936252745435198, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	valid_0's l1: 1.49838
# [I 2024-10-24 16:01:29,596] Trial 27 finished with value: 28940146.8151308 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 51, 'max_depth': 8, 'max_bin': 315, 'min_data_in_leaf': 73, 'bagging_fraction': 0.8313129855208855, 'bagging_freq': 3, 'lambda_l1': 7, 'lambda_l2': 15, 'min_split_gain': 8, 'colsample_bytree': 0.4682012110562144, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [633]	valid_0's l1: 1.45175
# [I 2024-10-24 16:01:29,886] Trial 28 finished with value: 28310757.549559373 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 60, 'max_depth': 6, 'max_bin': 199, 'min_data_in_leaf': 46, 'bagging_fraction': 0.9024117666330447, 'bagging_freq': 1, 'lambda_l1': 3, 'lambda_l2': 9, 'min_split_gain': 4, 'colsample_bytree': 0.345016063179636, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [480]	valid_0's l1: 1.41716
# [I 2024-10-24 16:01:30,240] Trial 29 finished with value: 28269670.902801078 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 39, 'max_depth': 9, 'max_bin': 413, 'min_data_in_leaf': 39, 'bagging_fraction': 0.6684178200806552, 'bagging_freq': 3, 'lambda_l1': 14, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.6565596001026509, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	valid_0's l1: 1.54926
# [I 2024-10-24 16:01:30,401] Trial 30 finished with value: 29462903.247150924 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 47, 'max_depth': 7, 'max_bin': 263, 'min_data_in_leaf': 93, 'bagging_fraction': 0.7346921384683376, 'bagging_freq': 2, 'lambda_l1': 13, 'lambda_l2': 18, 'min_split_gain': 12, 'colsample_bytree': 0.5464588379178456, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [290]	valid_0's l1: 1.42262
# [I 2024-10-24 16:01:30,677] Trial 31 finished with value: 27736556.961321045 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 30, 'max_depth': 6, 'max_bin': 375, 'min_data_in_leaf': 89, 'bagging_fraction': 0.7713889791975747, 'bagging_freq': 3, 'lambda_l1': 4, 'lambda_l2': 18, 'min_split_gain': 2, 'colsample_bytree': 0.6845069692874783, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [176]	valid_0's l1: 1.46533
# [I 2024-10-24 16:01:30,871] Trial 32 finished with value: 28050046.627929684 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 26, 'max_depth': 6, 'max_bin': 361, 'min_data_in_leaf': 66, 'bagging_fraction': 0.7735527328426873, 'bagging_freq': 4, 'lambda_l1': 7, 'lambda_l2': 17, 'min_split_gain': 3, 'colsample_bytree': 0.6848967027595413, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [367]	valid_0's l1: 1.55264
# [I 2024-10-24 16:01:31,063] Trial 33 finished with value: 30267694.702282548 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 34, 'max_depth': 5, 'max_bin': 442, 'min_data_in_leaf': 99, 'bagging_fraction': 0.6109704636545882, 'bagging_freq': 4, 'lambda_l1': 4, 'lambda_l2': 19, 'min_split_gain': 5, 'colsample_bytree': 0.41634216692694476, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [761]	valid_0's l1: 1.38879
# [I 2024-10-24 16:01:31,672] Trial 34 finished with value: 27901815.948390845 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 22, 'max_depth': 7, 'max_bin': 325, 'min_data_in_leaf': 58, 'bagging_fraction': 0.8362064347091224, 'bagging_freq': 3, 'lambda_l1': 5, 'lambda_l2': 14, 'min_split_gain': 1, 'colsample_bytree': 0.7447144174885629, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [635]	valid_0's l1: 1.42146
# [I 2024-10-24 16:01:32,079] Trial 35 finished with value: 28352463.823942624 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 42, 'max_depth': 5, 'max_bin': 240, 'min_data_in_leaf': 84, 'bagging_fraction': 0.7435931575029011, 'bagging_freq': 2, 'lambda_l1': 10, 'lambda_l2': 17, 'min_split_gain': 1, 'colsample_bytree': 0.4997388266014088, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 15 with value: 27621185.47923853.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [268]	valid_0's l1: 1.43723
# [I 2024-10-24 16:01:32,312] Trial 36 finished with value: 27521284.2262127 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 27, 'max_depth': 6, 'max_bin': 374, 'min_data_in_leaf': 72, 'bagging_fraction': 0.8742339988444854, 'bagging_freq': 3, 'lambda_l1': 6, 'lambda_l2': 19, 'min_split_gain': 3, 'colsample_bytree': 0.642045300287737, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l1: 1.44397
# [I 2024-10-24 16:01:32,515] Trial 37 finished with value: 27735310.403653264 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 31, 'max_depth': 7, 'max_bin': 398, 'min_data_in_leaf': 48, 'bagging_fraction': 0.8791574063493808, 'bagging_freq': 4, 'lambda_l1': 6, 'lambda_l2': 17, 'min_split_gain': 3, 'colsample_bytree': 0.6363988781753563, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [157]	valid_0's l1: 1.4629
# [I 2024-10-24 16:01:32,702] Trial 38 finished with value: 28345128.5859661 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 38, 'max_depth': 8, 'max_bin': 412, 'min_data_in_leaf': 47, 'bagging_fraction': 0.9325667166918585, 'bagging_freq': 4, 'lambda_l1': 6, 'lambda_l2': 15, 'min_split_gain': 6, 'colsample_bytree': 0.6296003019844166, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	valid_0's l1: 1.49175
# [I 2024-10-24 16:01:32,887] Trial 39 finished with value: 28418197.692444526 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 69, 'max_depth': 7, 'max_bin': 495, 'min_data_in_leaf': 39, 'bagging_fraction': 0.8846398197664066, 'bagging_freq': 5, 'lambda_l1': 6, 'lambda_l2': 7, 'min_split_gain': 8, 'colsample_bytree': 0.8269517934385594, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [163]	valid_0's l1: 1.43912
# [I 2024-10-24 16:01:33,153] Trial 40 finished with value: 27631517.924475364 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 49, 'max_depth': 8, 'max_bin': 448, 'min_data_in_leaf': 52, 'bagging_fraction': 0.9618312717366916, 'bagging_freq': 4, 'lambda_l1': 8, 'lambda_l2': 12, 'min_split_gain': 3, 'colsample_bytree': 0.5759236757722438, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [168]	valid_0's l1: 1.44046
# [I 2024-10-24 16:01:33,379] Trial 41 finished with value: 27601393.336332526 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 50, 'max_depth': 8, 'max_bin': 467, 'min_data_in_leaf': 50, 'bagging_fraction': 0.951768969636764, 'bagging_freq': 4, 'lambda_l1': 8, 'lambda_l2': 13, 'min_split_gain': 3, 'colsample_bytree': 0.5780368230669126, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	valid_0's l1: 1.46887
# [I 2024-10-24 16:01:33,585] Trial 42 finished with value: 28067866.28890624 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 53, 'max_depth': 8, 'max_bin': 467, 'min_data_in_leaf': 53, 'bagging_fraction': 0.9563671565267071, 'bagging_freq': 4, 'lambda_l1': 8, 'lambda_l2': 12, 'min_split_gain': 5, 'colsample_bytree': 0.5746996402653693, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [235]	valid_0's l1: 1.60101
# [I 2024-10-24 16:01:33,759] Trial 43 finished with value: 30535920.371623024 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 61, 'max_depth': 9, 'max_bin': 463, 'min_data_in_leaf': 61, 'bagging_fraction': 0.9649943242437621, 'bagging_freq': 4, 'lambda_l1': 8, 'lambda_l2': 10, 'min_split_gain': 15, 'colsample_bytree': 0.44433125972799026, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [161]	valid_0's l1: 1.445
# [I 2024-10-24 16:01:33,961] Trial 44 finished with value: 27727702.930423025 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 50, 'max_depth': 8, 'max_bin': 439, 'min_data_in_leaf': 41, 'bagging_fraction': 0.9260553102432257, 'bagging_freq': 4, 'lambda_l1': 11, 'lambda_l2': 13, 'min_split_gain': 3, 'colsample_bytree': 0.7134111652812816, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	valid_0's l1: 1.46864
# [I 2024-10-24 16:01:34,145] Trial 45 finished with value: 28405514.4822434 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 57, 'max_depth': 8, 'max_bin': 474, 'min_data_in_leaf': 73, 'bagging_fraction': 0.9161928751369071, 'bagging_freq': 5, 'lambda_l1': 10, 'lambda_l2': 12, 'min_split_gain': 4, 'colsample_bytree': 0.6249231138897349, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 1.46311
# [I 2024-10-24 16:01:34,334] Trial 46 finished with value: 28263176.33514495 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 64, 'max_depth': 9, 'max_bin': 415, 'min_data_in_leaf': 59, 'bagging_fraction': 0.9411359494247454, 'bagging_freq': 3, 'lambda_l1': 8, 'lambda_l2': 14, 'min_split_gain': 6, 'colsample_bytree': 0.5100182601880962, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [345]	valid_0's l1: 1.39296
# [I 2024-10-24 16:01:34,813] Trial 47 finished with value: 27990251.415402967 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 75, 'max_depth': 8, 'max_bin': 452, 'min_data_in_leaf': 67, 'bagging_fraction': 0.8692626285489535, 'bagging_freq': 3, 'lambda_l1': 2, 'lambda_l2': 11, 'min_split_gain': 1, 'colsample_bytree': 0.9760628746252864, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [266]	valid_0's l1: 1.51293
# [I 2024-10-24 16:01:35,023] Trial 48 finished with value: 29040639.758096922 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 45, 'max_depth': 7, 'max_bin': 359, 'min_data_in_leaf': 30, 'bagging_fraction': 0.9667902821794087, 'bagging_freq': 5, 'lambda_l1': 11, 'lambda_l2': 8, 'min_split_gain': 5, 'colsample_bytree': 0.38111694249285044, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [633]	valid_0's l1: 1.57536
# [I 2024-10-24 16:01:35,296] Trial 49 finished with value: 31502481.376956213 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 93, 'max_depth': 8, 'max_bin': 332, 'min_data_in_leaf': 51, 'bagging_fraction': 0.8378484168534975, 'bagging_freq': 4, 'lambda_l1': 5, 'lambda_l2': 13, 'min_split_gain': 7, 'colsample_bytree': 0.2000386580376588, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	valid_0's l1: 1.45651
# [I 2024-10-24 16:01:35,546] Trial 50 finished with value: 28314491.792323288 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 26, 'max_depth': 9, 'max_bin': 500, 'min_data_in_leaf': 132, 'bagging_fraction': 0.9145265769099115, 'bagging_freq': 3, 'lambda_l1': 7, 'lambda_l2': 16, 'min_split_gain': 3, 'colsample_bytree': 0.573227049905928, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 36 with value: 27521284.2262127.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [171]	valid_0's l1: 1.44483
# [I 2024-10-24 16:01:35,782] Trial 51 finished with value: 27452975.205962483 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 49, 'max_depth': 8, 'max_bin': 431, 'min_data_in_leaf': 42, 'bagging_fraction': 0.976587078542471, 'bagging_freq': 4, 'lambda_l1': 11, 'lambda_l2': 13, 'min_split_gain': 2, 'colsample_bytree': 0.7264189927297943, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 51 with value: 27452975.205962483.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [165]	valid_0's l1: 1.43826
# [I 2024-10-24 16:01:36,015] Trial 52 finished with value: 28108251.202790234 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 47, 'max_depth': 7, 'max_bin': 396, 'min_data_in_leaf': 43, 'bagging_fraction': 0.9781839782249596, 'bagging_freq': 4, 'lambda_l1': 9, 'lambda_l2': 11, 'min_split_gain': 2, 'colsample_bytree': 0.8038434050148624, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 51 with value: 27452975.205962483.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [827]	valid_0's l1: 1.36051
# [I 2024-10-24 16:01:36,971] Trial 53 finished with value: 27222582.5518719 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 36, 'max_depth': 8, 'max_bin': 289, 'min_data_in_leaf': 55, 'bagging_fraction': 0.9392348605170562, 'bagging_freq': 4, 'lambda_l1': 10, 'lambda_l2': 12, 'min_split_gain': 0, 'colsample_bytree': 0.5337337322270094, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [838]	valid_0's l1: 1.37353
# [I 2024-10-24 16:01:38,155] Trial 54 finished with value: 27857373.02517197 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 37, 'max_depth': 9, 'max_bin': 427, 'min_data_in_leaf': 36, 'bagging_fraction': 0.9462050576778341, 'bagging_freq': 4, 'lambda_l1': 13, 'lambda_l2': 6, 'min_split_gain': 0, 'colsample_bytree': 0.736590847545057, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [531]	valid_0's l1: 1.40241
# [I 2024-10-24 16:01:38,759] Trial 55 finished with value: 28687291.627889745 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 55, 'max_depth': 8, 'max_bin': 92, 'min_data_in_leaf': 50, 'bagging_fraction': 0.5051937981927236, 'bagging_freq': 5, 'lambda_l1': 10, 'lambda_l2': 10, 'min_split_gain': 0, 'colsample_bytree': 0.7175015507146927, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [186]	valid_0's l1: 1.42388
# [I 2024-10-24 16:01:39,009] Trial 56 finished with value: 27988560.866986647 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 42, 'max_depth': 8, 'max_bin': 287, 'min_data_in_leaf': 56, 'bagging_fraction': 0.9971748479384341, 'bagging_freq': 4, 'lambda_l1': 15, 'lambda_l2': 4, 'min_split_gain': 1, 'colsample_bytree': 0.7981153371414791, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's l1: 1.57118
# [I 2024-10-24 16:01:39,163] Trial 57 finished with value: 29514673.62471268 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 49, 'max_depth': 9, 'max_bin': 486, 'min_data_in_leaf': 77, 'bagging_fraction': 0.9802877331683051, 'bagging_freq': 4, 'lambda_l1': 12, 'lambda_l2': 13, 'min_split_gain': 18, 'colsample_bytree': 0.9151595336240614, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [241]	valid_0's l1: 1.43403
# [I 2024-10-24 16:01:39,416] Trial 58 finished with value: 27727045.221925937 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 41, 'max_depth': 8, 'max_bin': 451, 'min_data_in_leaf': 68, 'bagging_fraction': 0.9689044493209176, 'bagging_freq': 5, 'lambda_l1': 9, 'lambda_l2': 12, 'min_split_gain': 3, 'colsample_bytree': 0.5325959727042314, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [856]	valid_0's l1: 1.43996
# [I 2024-10-24 16:01:39,940] Trial 59 finished with value: 29003022.650541894 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 46, 'max_depth': 5, 'max_bin': 169, 'min_data_in_leaf': 61, 'bagging_fraction': 0.9437655879439736, 'bagging_freq': 4, 'lambda_l1': 10, 'lambda_l2': 19, 'min_split_gain': 1, 'colsample_bytree': 0.44652717032569966, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [856]	valid_0's l1: 1.3895
# [I 2024-10-24 16:01:40,772] Trial 60 finished with value: 28354190.16633908 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 36, 'max_depth': 6, 'max_bin': 479, 'min_data_in_leaf': 51, 'bagging_fraction': 0.9148234388192124, 'bagging_freq': 3, 'lambda_l1': 18, 'lambda_l2': 14, 'min_split_gain': 0, 'colsample_bytree': 0.5719953767662982, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [205]	valid_0's l1: 1.42978
# [I 2024-10-24 16:01:41,022] Trial 61 finished with value: 27737613.75725731 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 33, 'max_depth': 8, 'max_bin': 245, 'min_data_in_leaf': 56, 'bagging_fraction': 0.8924227032609078, 'bagging_freq': 4, 'lambda_l1': 11, 'lambda_l2': 15, 'min_split_gain': 2, 'colsample_bytree': 0.6219756234764489, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [604]	valid_0's l1: 1.45145
# [I 2024-10-24 16:01:41,337] Trial 62 finished with value: 27903230.986856535 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 24, 'max_depth': 7, 'max_bin': 286, 'min_data_in_leaf': 63, 'bagging_fraction': 0.8235623587403135, 'bagging_freq': 1, 'lambda_l1': 8, 'lambda_l2': 11, 'min_split_gain': 4, 'colsample_bytree': 0.5078487342924003, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [392]	valid_0's l1: 1.48695
# [I 2024-10-24 16:01:41,625] Trial 63 finished with value: 28632463.389769945 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 39, 'max_depth': 3, 'max_bin': 218, 'min_data_in_leaf': 45, 'bagging_fraction': 0.8703421831244044, 'bagging_freq': 2, 'lambda_l1': 9, 'lambda_l2': 12, 'min_split_gain': 2, 'colsample_bytree': 0.4781097201707752, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [210]	valid_0's l1: 1.45328
# [I 2024-10-24 16:01:41,842] Trial 64 finished with value: 27942359.01694364 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 27, 'max_depth': 6, 'max_bin': 303, 'min_data_in_leaf': 71, 'bagging_fraction': 0.8552932613871793, 'bagging_freq': 4, 'lambda_l1': 7, 'lambda_l2': 13, 'min_split_gain': 3, 'colsample_bytree': 0.5944972404862117, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [112]	valid_0's l1: 1.54464
# [I 2024-10-24 16:01:42,015] Trial 65 finished with value: 29067497.96955704 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 33, 'max_depth': 7, 'max_bin': 368, 'min_data_in_leaf': 37, 'bagging_fraction': 0.904977364107408, 'bagging_freq': 2, 'lambda_l1': 13, 'lambda_l2': 9, 'min_split_gain': 14, 'colsample_bytree': 0.6571692832893951, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 53 with value: 27222582.5518719.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [280]	valid_0's l1: 1.40865
# [I 2024-10-24 16:01:42,296] Trial 66 finished with value: 27215449.807524852 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 57, 'max_depth': 8, 'max_bin': 426, 'min_data_in_leaf': 43, 'bagging_fraction': 0.9611284174468957, 'bagging_freq': 3, 'lambda_l1': 10, 'lambda_l2': 14, 'min_split_gain': 2, 'colsample_bytree': 0.5562653436685762, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 66 with value: 27215449.807524852.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [857]	valid_0's l1: 1.36833
# [I 2024-10-24 16:01:43,423] Trial 67 finished with value: 26905489.054130662 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 64, 'max_depth': 8, 'max_bin': 391, 'min_data_in_leaf': 43, 'bagging_fraction': 0.9526177241623821, 'bagging_freq': 3, 'lambda_l1': 11, 'lambda_l2': 14, 'min_split_gain': 0, 'colsample_bytree': 0.5524835312038374, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [854]	valid_0's l1: 1.36773
# [I 2024-10-24 16:01:44,568] Trial 68 finished with value: 27828501.764588255 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 63, 'max_depth': 9, 'max_bin': 398, 'min_data_in_leaf': 33, 'bagging_fraction': 0.9285997255155857, 'bagging_freq': 3, 'lambda_l1': 12, 'lambda_l2': 14, 'min_split_gain': 0, 'colsample_bytree': 0.5458443904162106, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [172]	valid_0's l1: 1.4102
# [I 2024-10-24 16:01:44,840] Trial 69 finished with value: 27075967.66412617 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 74, 'max_depth': 8, 'max_bin': 387, 'min_data_in_leaf': 43, 'bagging_fraction': 0.9804113043334094, 'bagging_freq': 3, 'lambda_l1': 11, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.7052247092864232, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [295]	valid_0's l1: 1.40327
# [I 2024-10-24 16:01:45,143] Trial 70 finished with value: 27027005.92284812 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 74, 'max_depth': 8, 'max_bin': 350, 'min_data_in_leaf': 44, 'bagging_fraction': 0.9834735890634263, 'bagging_freq': 3, 'lambda_l1': 11, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.6140968859572584, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [271]	valid_0's l1: 1.40632
# [I 2024-10-24 16:01:45,469] Trial 71 finished with value: 27201824.066619094 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 74, 'max_depth': 8, 'max_bin': 349, 'min_data_in_leaf': 42, 'bagging_fraction': 0.9851708908693185, 'bagging_freq': 3, 'lambda_l1': 11, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.70224306415861, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [333]	valid_0's l1: 1.40241
# [I 2024-10-24 16:01:45,819] Trial 72 finished with value: 27588083.484415587 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 74, 'max_depth': 8, 'max_bin': 348, 'min_data_in_leaf': 42, 'bagging_fraction': 0.9832491159867001, 'bagging_freq': 3, 'lambda_l1': 11, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.7779753524148137, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	valid_0's l1: 1.41201
# [I 2024-10-24 16:01:46,099] Trial 73 finished with value: 26978285.4149565 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 81, 'max_depth': 8, 'max_bin': 387, 'min_data_in_leaf': 31, 'bagging_fraction': 0.9967527483875721, 'bagging_freq': 3, 'lambda_l1': 14, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.712385017779104, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [206]	valid_0's l1: 1.4181
# [I 2024-10-24 16:01:46,396] Trial 74 finished with value: 27372895.218941502 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 81, 'max_depth': 8, 'max_bin': 385, 'min_data_in_leaf': 30, 'bagging_fraction': 0.9990150451564399, 'bagging_freq': 3, 'lambda_l1': 14, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.7053785619224671, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	valid_0's l1: 1.40719
# [I 2024-10-24 16:01:46,667] Trial 75 finished with value: 27476236.536176458 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 84, 'max_depth': 9, 'max_bin': 352, 'min_data_in_leaf': 30, 'bagging_fraction': 0.9985721224196941, 'bagging_freq': 3, 'lambda_l1': 14, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.7015414083636531, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [685]	valid_0's l1: 1.37997
# [I 2024-10-24 16:01:47,710] Trial 76 finished with value: 27645976.17121061 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 80, 'max_depth': 8, 'max_bin': 384, 'min_data_in_leaf': 35, 'bagging_fraction': 0.999391962793069, 'bagging_freq': 3, 'lambda_l1': 17, 'lambda_l2': 17, 'min_split_gain': 0, 'colsample_bytree': 0.7656360508341323, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 67 with value: 26905489.054130662.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [199]	valid_0's l1: 1.40461
# [I 2024-10-24 16:01:47,984] Trial 77 finished with value: 26888408.456418626 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 90, 'max_depth': 8, 'max_bin': 323, 'min_data_in_leaf': 38, 'bagging_fraction': 0.9832734416021521, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.8391161937150541, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [336]	valid_0's l1: 1.38738
# [I 2024-10-24 16:01:48,639] Trial 78 finished with value: 27293125.520168755 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 87, 'max_depth': 8, 'max_bin': 319, 'min_data_in_leaf': 38, 'bagging_fraction': 0.954603625263681, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 16, 'min_split_gain': 0, 'colsample_bytree': 0.8861036689348561, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's l1: 1.41756
# [I 2024-10-24 16:01:48,899] Trial 79 finished with value: 27465857.150124095 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 73, 'max_depth': 9, 'max_bin': 330, 'min_data_in_leaf': 47, 'bagging_fraction': 0.9823027044173093, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.839263675561451, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [100]	valid_0's l1: 1.59932
# [I 2024-10-24 16:01:49,052] Trial 80 finished with value: 29516242.15030041 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 77, 'max_depth': 8, 'max_bin': 345, 'min_data_in_leaf': 110, 'bagging_fraction': 0.9387842026379395, 'bagging_freq': 3, 'lambda_l1': 13, 'lambda_l2': 17, 'min_split_gain': 20, 'colsample_bytree': 0.8645054689198564, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [702]	valid_0's l1: 1.38103
# [I 2024-10-24 16:01:50,179] Trial 81 finished with value: 27093544.57879978 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 92, 'max_depth': 8, 'max_bin': 319, 'min_data_in_leaf': 39, 'bagging_fraction': 0.9574742397206603, 'bagging_freq': 3, 'lambda_l1': 16, 'lambda_l2': 14, 'min_split_gain': 0, 'colsample_bytree': 0.890150118014833, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [856]	valid_0's l1: 1.38191
# [I 2024-10-24 16:01:51,407] Trial 82 finished with value: 27533439.177175224 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 91, 'max_depth': 8, 'max_bin': 310, 'min_data_in_leaf': 40, 'bagging_fraction': 0.9701740754854562, 'bagging_freq': 3, 'lambda_l1': 16, 'lambda_l2': 14, 'min_split_gain': 0, 'colsample_bytree': 0.9281290907743871, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [158]	valid_0's l1: 1.44049
# [I 2024-10-24 16:01:51,659] Trial 83 finished with value: 27655096.534943204 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 96, 'max_depth': 8, 'max_bin': 337, 'min_data_in_leaf': 44, 'bagging_fraction': 0.9872837854595901, 'bagging_freq': 3, 'lambda_l1': 17, 'lambda_l2': 14, 'min_split_gain': 2, 'colsample_bytree': 0.9486506410874218, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [854]	valid_0's l1: 1.36804
# [I 2024-10-24 16:01:52,804] Trial 84 finished with value: 27143446.957241137 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 70, 'max_depth': 8, 'max_bin': 408, 'min_data_in_leaf': 35, 'bagging_fraction': 0.9540263419291534, 'bagging_freq': 3, 'lambda_l1': 12, 'lambda_l2': 16, 'min_split_gain': 0, 'colsample_bytree': 0.6170431711333556, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [193]	valid_0's l1: 1.40603
# [I 2024-10-24 16:01:53,161] Trial 85 finished with value: 27202100.226873297 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 70, 'max_depth': 8, 'max_bin': 406, 'min_data_in_leaf': 33, 'bagging_fraction': 0.9591716340511195, 'bagging_freq': 3, 'lambda_l1': 12, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.6746654846723852, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l1: 1.40106
# [I 2024-10-24 16:01:53,470] Trial 86 finished with value: 27080290.64519181 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 71, 'max_depth': 9, 'max_bin': 366, 'min_data_in_leaf': 34, 'bagging_fraction': 0.9252008862942751, 'bagging_freq': 3, 'lambda_l1': 12, 'lambda_l2': 16, 'min_split_gain': 1, 'colsample_bytree': 0.6686900418772136, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	valid_0's l1: 1.53916
# [I 2024-10-24 16:01:53,629] Trial 87 finished with value: 29405031.68213223 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 66, 'max_depth': 9, 'max_bin': 362, 'min_data_in_leaf': 33, 'bagging_fraction': 0.975268186760159, 'bagging_freq': 3, 'lambda_l1': 16, 'lambda_l2': 17, 'min_split_gain': 11, 'colsample_bytree': 0.6046548691179382, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [327]	valid_0's l1: 1.38072
# [I 2024-10-24 16:01:54,310] Trial 88 finished with value: 27188190.702848084 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 77, 'max_depth': 9, 'max_bin': 379, 'min_data_in_leaf': 38, 'bagging_fraction': 0.9256202258355609, 'bagging_freq': 3, 'lambda_l1': 13, 'lambda_l2': 18, 'min_split_gain': 0, 'colsample_bytree': 0.8550814139032846, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [529]	valid_0's l1: 1.38205
# [I 2024-10-24 16:01:55,306] Trial 89 finished with value: 27255885.19947288 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 71, 'max_depth': 9, 'max_bin': 373, 'min_data_in_leaf': 36, 'bagging_fraction': 0.9175018199904509, 'bagging_freq': 3, 'lambda_l1': 13, 'lambda_l2': 18, 'min_split_gain': 0, 'colsample_bytree': 0.8549452354770387, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's l1: 1.43735
# [I 2024-10-24 16:01:55,544] Trial 90 finished with value: 27569569.765349623 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 77, 'max_depth': 9, 'max_bin': 394, 'min_data_in_leaf': 39, 'bagging_fraction': 0.9314409192078035, 'bagging_freq': 3, 'lambda_l1': 14, 'lambda_l2': 15, 'min_split_gain': 2, 'colsample_bytree': 0.8821721755544619, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [194]	valid_0's l1: 1.40743
# [I 2024-10-24 16:01:55,829] Trial 91 finished with value: 26925805.64690713 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 88, 'max_depth': 9, 'max_bin': 355, 'min_data_in_leaf': 48, 'bagging_fraction': 0.9523525804632326, 'bagging_freq': 3, 'lambda_l1': 13, 'lambda_l2': 17, 'min_split_gain': 1, 'colsample_bytree': 0.6734477226377386, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [258]	valid_0's l1: 1.40385
# [I 2024-10-24 16:01:56,115] Trial 92 finished with value: 27244041.433722097 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 88, 'max_depth': 9, 'max_bin': 384, 'min_data_in_leaf': 48, 'bagging_fraction': 0.9499906244428005, 'bagging_freq': 3, 'lambda_l1': 12, 'lambda_l2': 17, 'min_split_gain': 1, 'colsample_bytree': 0.6454541161765422, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's l1: 1.38259
# [I 2024-10-24 16:01:56,947] Trial 93 finished with value: 27059247.59164671 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 84, 'max_depth': 9, 'max_bin': 359, 'min_data_in_leaf': 36, 'bagging_fraction': 0.9256605454605886, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 18, 'min_split_gain': 0, 'colsample_bytree': 0.9935965647822234, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [175]	valid_0's l1: 1.40909
# [I 2024-10-24 16:01:57,198] Trial 94 finished with value: 27088964.266861763 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 84, 'max_depth': 9, 'max_bin': 323, 'min_data_in_leaf': 35, 'bagging_fraction': 0.9533327711066657, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.6823358488557871, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [163]	valid_0's l1: 1.41986
# [I 2024-10-24 16:01:57,469] Trial 95 finished with value: 27659336.539104994 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 84, 'max_depth': 9, 'max_bin': 321, 'min_data_in_leaf': 31, 'bagging_fraction': 0.9038094228745184, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.9876832473763906, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [154]	valid_0's l1: 1.44304
# [I 2024-10-24 16:01:57,703] Trial 96 finished with value: 27782950.058207784 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 93, 'max_depth': 9, 'max_bin': 357, 'min_data_in_leaf': 39, 'bagging_fraction': 0.9672895292992115, 'bagging_freq': 3, 'lambda_l1': 17, 'lambda_l2': 17, 'min_split_gain': 2, 'colsample_bytree': 0.665449313613843, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [145]	valid_0's l1: 1.4391
# [I 2024-10-24 16:01:57,945] Trial 97 finished with value: 27708390.056407113 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 90, 'max_depth': 9, 'max_bin': 338, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9879032562283308, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 18, 'min_split_gain': 2, 'colsample_bytree': 0.780825577680855, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l1: 1.43577
# [I 2024-10-24 16:01:58,232] Trial 98 finished with value: 27264779.724940926 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 82, 'max_depth': 9, 'max_bin': 367, 'min_data_in_leaf': 32, 'bagging_fraction': 0.940122040537329, 'bagging_freq': 3, 'lambda_l1': 20, 'lambda_l2': 15, 'min_split_gain': 1, 'colsample_bytree': 0.9569700518790966, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [653]	valid_0's l1: 1.37241
# [I 2024-10-24 16:01:59,274] Trial 99 finished with value: 27550288.774246495 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 98, 'max_depth': 9, 'max_bin': 327, 'min_data_in_leaf': 36, 'bagging_fraction': 0.9680229323062903, 'bagging_freq': 3, 'lambda_l1': 16, 'lambda_l2': 20, 'min_split_gain': 0, 'colsample_bytree': 0.6861534188423111, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 77 with value: 26888408.456418626.

# %%
study_lgbm.best_params
# Out:
# {'n_estimators': 857,
#  'learning_rate': 0.045309611206922125,
#  'num_leaves': 39,
#  'max_depth': 9,
#  'max_bin': 79,
#  'min_data_in_leaf': 38,
#  'bagging_fraction': 0.7830367186846483,
#  'bagging_freq': 3,
#  'lambda_l1': 3,
#  'lambda_l2': 6,
#  'min_split_gain': 2,
#  'colsample_bytree': 0.6636806512095652,
#  'objective': 'mae',
#  'verbosity': -1,
#  'random_state': 42}

# %%
print(f'Best value = {study_lgbm.best_value}')
# Out:
# Best value = 26888408.456418626

# %% [markdown]
# - обучим модель с лучшими параметрами и оценим ее метрики

# %%
lgbm_params = {
    'n_estimators': 857,
    'learning_rate': 0.045309611206922125,
    'num_leaves': 39,
    'max_depth': 9,
    'max_bin': 79,
    'min_data_in_leaf': 38,
    'bagging_fraction': 0.7830367186846483,
    'bagging_freq': 3,
    'lambda_l1': 3,
    'lambda_l2': 6,
    'min_split_gain': 2,
    'colsample_bytree': 0.6636806512095652,
    'objective': 'mae',
    'verbosity': -1,
    'random_state': 42
}

# %%
# обучение модели на лучших параметрах для оценки метрик
eval_set = [(X_val, y_val)]

lgbm_optuna = LGBMRegressor(**lgbm_params)
lgbm_optuna.fit(X_train,
                y_train,
                eval_metric="mae",
                categorical_feature=cat_features,
                eval_set=eval_set,
                callbacks=[early_stopping(stopping_rounds=100)])

y_pred = lgbm_optuna.predict(X_test)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l1: 1.40474

# %% [markdown]
# ## Метрики

# %%
def r2_adjusted(y_true: np.ndarray, y_pred: np.ndarray,
                X_test: np.ndarray) -> float:
    '''
    Вычисление коэффициента детерминации для множественной регрессии
    
    Parameters
    -----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели
    X_test: np.ndarray
        тестовые значения X
    
    Returns
    ----------
    Значение метрики
    '''
    n_objects = len(y_true)
    n_features = X_test.shape[1]
    r2 = r2_score(y_true, y_pred)
    return 1 - (1 - r2) * (n_objects - 1) / (n_objects - n_features - 1)


def wape(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    '''
    Вычисление взвешенной абсолютной процентной ошибки
    
    Parameters
    -----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели
    
    Returns
    ----------
    Значение метрики
    '''
    return np.sum(np.abs(y_pred - y_true)) * 100 / np.sum(y_true)


def rmsle(y_true: np.ndarray, y_pred: np.ndarray) -> np.float64:
    '''
    Вычисление среднеквадратической логарифмической ошибки
    
    Parameters
    -----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели 
        
    Returns
    ----------
    Значение метрики
    '''
    try:
        return np.sqrt(mean_squared_log_error(y_true, y_pred))
    except:
        return None


def get_metrics(y_test: np.ndarray, y_pred: np.ndarray, X_test: np.ndarray,
                name: str) -> pd.DataFrame:
    '''
    Создание таблицы с основными метриками для модели
    
    Parameters
    ----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели
    X_test: np.ndarray
        тестовые значения X
    Returns
    ----------
    датафрейм с метриками
    '''
    metrics = pd.DataFrame()

    metrics['model'] = [name]
    metrics['MSE'] = mean_squared_error(y_test, y_pred)
    metrics['RMSE'] = np.sqrt(mean_squared_error(y_test, y_pred))
    metrics['RMSLE'] = rmsle(y_test, y_pred)
    metrics['MAE'] = mean_absolute_error(y_test, y_pred)
    metrics['R2 adjusted'] = r2_adjusted(y_test, y_pred, X_test)
    metrics['WAPE_%'] = wape(y_test, y_pred)

    return metrics

# %%
def check_overfitting(model: LGBMRegressor, X_train: np.ndarray,
                      y_train: np.ndarray, X_test: np.ndarray,
                      y_test: np.ndarray, metric: Callable,
                      model_name: str) -> None:
    '''
    Проверяет переобучилась ли модель
    
    Parameters
    ----------
    model: LGBMRegressor
        модель
    X_train: np.ndarray
        тренировочные данные
    y_train: np.ndarray
        тренировочные значения y
    X_test: np.ndarray
        тестовые данные
    y_test: np.ndarray
        тестовые значения y
    metric: Callable
        функция-метрика для оценки переобучения
    model_name: str
        название модели
    
    Returns
    ----------
    Данные о переобучении и метрики на train и test
    '''
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    metric_train = metric(np.exp(y_train), np.exp(y_pred_train))
    metric_test = metric(np.exp(y_test), np.exp(y_pred_test))

    print(f'Рассчет переобучения {model_name}')
    print(f'{metric.__name__} на train: {round(metric_train, 2)}')
    print(f'{metric.__name__} на test: {round(metric_test, 2)}')
    print(
        f'delta = {round((abs(metric_train - metric_test) / metric_test*100), 1)}%'
    )

# %%
# импорт метрик с baseline
metrics = pd.read_csv('metrics/metrics.csv')

# %%
metrics = pd.concat([
    metrics,
    get_metrics(np.exp(y_train), np.exp(lgbm_optuna.predict(X_train)), X_train,
                'LGBMTunedTrain'),
    get_metrics(np.exp(y_test), np.exp(y_pred), X_test, 'LGBMTunedTest')
])

# %%
metrics.set_index('model')
# Out:
#                                 MSE          RMSE     RMSLE           MAE  \
# model
# CatBoostBaselineTrain  5.894929e+15  7.677844e+07  1.799804  2.420852e+07
# CatBoostBaselineTest   5.843035e+15  7.643975e+07  1.944247  2.780998e+07
# LGBMBaselineTrain      6.377899e+15  7.986175e+07  1.760601  2.259239e+07
# LGBMBaselineTest       5.542784e+15  7.444987e+07  1.973105  2.715035e+07
# LGBMTunedTrain         7.189569e+15  8.479133e+07  1.797810  2.542100e+07
# LGBMTunedTest          5.274787e+15  7.262773e+07  1.953873  2.671265e+07
#
#                        R2 adjusted     WAPE_%
# model
# CatBoostBaselineTrain     0.715322  48.974804
# CatBoostBaselineTest      0.658584  55.508199
# LGBMBaselineTrain         0.691999  45.705303
# LGBMBaselineTest          0.676128  54.191586
# LGBMTunedTrain            0.652802  51.427701
# LGBMTunedTest             0.691788  53.317938

# %% [markdown]
# - в результате подбора параметров значение MAE на тренировочных данных немного ухудшилось, а на тестовых улучшилось
# - такая же ситуация и с другими метриками

# %%
# проверка на переобучение
check_overfitting(lgbm_optuna, X_train, y_train, X_test, y_test,
                  mean_absolute_error, 'LightGBMTuned')
# Out:
# Рассчет переобучения LightGBMTuned
# mean_absolute_error на train: 25421004.84
# mean_absolute_error на test: 26712648.19
# delta = 4.8%

# %% [markdown]
# - у baseline модели переобучение равнялось 16.8 процентам, то есть оно **уменьшилось почти в 4 раза**

# %% [markdown]
# # Кросс валидация

# %% [markdown]
# - оценим метрики модели с кросс валидацией

# %%
def cross_validation(X_train: pd.DataFrame, y_train: pd.Series,
                     X_test: pd.DataFrame, y_test: pd.Series, params: dict,
                     num_folds: int, random_state: int, cat_features):
    '''
    Функция для кросс валидации модели (метрика - MAE)
    
    Parameters
    ------------
    X_train: np.ndarray
        тренировочные данные
    y_train: np.ndarray
        тренировочные значения y
    X_test: np.ndarray
        тестовые данные
    y_test: np.ndarray
        тестовые значения y
    params: dict
        словарь с параметрами модели
    num_folds: int
        количество фолдов
    random_state: int
        значение random state
                     
    Returns
    ------------
        значения метрики на out-of-fold и предстказания модели на тесте
    '''

    folds = KFold(n_splits=num_folds, random_state=random_state, shuffle=True)
    score_oof = []
    predictions_test = []

    for fold, (train_index,
               test_index) in enumerate(folds.split(X_train, y_train)):
        X_train_, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
        y_train_, y_val = y_train.iloc[train_index], y_train.iloc[test_index]
        y_val_exp = np.exp(y_val)

        model = LGBMRegressor(**params)
        model.fit(X_train_,
                  y_train_,
                  eval_set=[(X_val, y_val)],
                  eval_metric="mae",
                  categorical_feature=cat_features)

        y_pred_val = np.exp(model.predict(X_val))
        y_pred = np.exp(model.predict(X_test))
        mae_oof = mean_absolute_error(y_val_exp, y_pred_val)

        print(f'{fold + 1} MAE score = {round(mae_oof, 3)}')
        print('-----')

        score_oof.append(mae_oof)
        predictions_test.append(y_pred)

    return score_oof, predictions_test

# %%
# получение предсказаний с помощтю кросс валидации
score_oof, predictions_test = cross_validation(X_train_,
                                               y_train_,
                                               X_test,
                                               y_test,
                                               params=lgbm_params,
                                               num_folds=N_FOLDS,
                                               random_state=RAND,
                                               cat_features=cat_features)
# Out:
# 1 MAE score = 27720116.185
# -----
# 2 MAE score = 28178852.917
# -----
# 3 MAE score = 31213886.631
# -----
# 4 MAE score = 29856073.74
# -----
# 5 MAE score = 26441594.882
# -----

# %%
pred_test_cv = np.mean(predictions_test, axis=0)

print(f'Среднее значение MAE на out-of-fold: {round(np.mean(score_oof), 3)}')
print(f'std MAE на out-of-fold: {round(np.std(score_oof), 3)}')
print(
    f'Значение MAE на тестовых данных: {round(mean_absolute_error(np.exp(y_test), pred_test_cv), 3)}'
)
# Out:
# Среднее значение MAE на out-of-fold: 28682104.871
# std MAE на out-of-fold: 1672524.533
# Значение MAE на тестовых данных: 26811477.259

# %%
metrics = pd.concat(
    [metrics,
     get_metrics(np.exp(y_test), pred_test_cv, X_test, 'LGBMCVTest')])

# %%
metrics.set_index('model').style.highlight_min(
    axis=0, color='lightblue').highlight_max(axis=0, color='lightpink')
# Out:
# <style type="text/css">
# #T_beba4_row0_col4, #T_beba4_row1_col3, #T_beba4_row1_col5, #T_beba4_row3_col2, #T_beba4_row4_col0, #T_beba4_row4_col1 {
#   background-color: lightpink;
# }
# #T_beba4_row2_col2, #T_beba4_row2_col3, #T_beba4_row2_col5, #T_beba4_row4_col4, #T_beba4_row6_col0, #T_beba4_row6_col1 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_beba4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_beba4_level0_col0" class="col_heading level0 col0" >MSE</th>
#       <th id="T_beba4_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_beba4_level0_col2" class="col_heading level0 col2" >RMSLE</th>
#       <th id="T_beba4_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_beba4_level0_col4" class="col_heading level0 col4" >R2 adjusted</th>
#       <th id="T_beba4_level0_col5" class="col_heading level0 col5" >WAPE_%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beba4_level0_row0" class="row_heading level0 row0" >CatBoostBaselineTrain</th>
#       <td id="T_beba4_row0_col0" class="data row0 col0" >5894928942723778.000000</td>
#       <td id="T_beba4_row0_col1" class="data row0 col1" >76778440.611436</td>
#       <td id="T_beba4_row0_col2" class="data row0 col2" >1.799804</td>
#       <td id="T_beba4_row0_col3" class="data row0 col3" >24208523.565597</td>
#       <td id="T_beba4_row0_col4" class="data row0 col4" >0.715322</td>
#       <td id="T_beba4_row0_col5" class="data row0 col5" >48.974804</td>
#     </tr>
#     <tr>
#       <th id="T_beba4_level0_row1" class="row_heading level0 row1" >CatBoostBaselineTest</th>
#       <td id="T_beba4_row1_col0" class="data row1 col0" >5843035434928676.000000</td>
#       <td id="T_beba4_row1_col1" class="data row1 col1" >76439750.358885</td>
#       <td id="T_beba4_row1_col2" class="data row1 col2" >1.944247</td>
#       <td id="T_beba4_row1_col3" class="data row1 col3" >27809983.773220</td>
#       <td id="T_beba4_row1_col4" class="data row1 col4" >0.658584</td>
#       <td id="T_beba4_row1_col5" class="data row1 col5" >55.508199</td>
#     </tr>
#     <tr>
#       <th id="T_beba4_level0_row2" class="row_heading level0 row2" >LGBMBaselineTrain</th>
#       <td id="T_beba4_row2_col0" class="data row2 col0" >6377899338583602.000000</td>
#       <td id="T_beba4_row2_col1" class="data row2 col1" >79861751.411947</td>
#       <td id="T_beba4_row2_col2" class="data row2 col2" >1.760601</td>
#       <td id="T_beba4_row2_col3" class="data row2 col3" >22592390.786591</td>
#       <td id="T_beba4_row2_col4" class="data row2 col4" >0.691999</td>
#       <td id="T_beba4_row2_col5" class="data row2 col5" >45.705303</td>
#     </tr>
#     <tr>
#       <th id="T_beba4_level0_row3" class="row_heading level0 row3" >LGBMBaselineTest</th>
#       <td id="T_beba4_row3_col0" class="data row3 col0" >5542783863964557.000000</td>
#       <td id="T_beba4_row3_col1" class="data row3 col1" >74449874.841833</td>
#       <td id="T_beba4_row3_col2" class="data row3 col2" >1.973105</td>
#       <td id="T_beba4_row3_col3" class="data row3 col3" >27150351.399408</td>
#       <td id="T_beba4_row3_col4" class="data row3 col4" >0.676128</td>
#       <td id="T_beba4_row3_col5" class="data row3 col5" >54.191586</td>
#     </tr>
#     <tr>
#       <th id="T_beba4_level0_row4" class="row_heading level0 row4" >LGBMTunedTrain</th>
#       <td id="T_beba4_row4_col0" class="data row4 col0" >7189569218544470.000000</td>
#       <td id="T_beba4_row4_col1" class="data row4 col1" >84791327.496062</td>
#       <td id="T_beba4_row4_col2" class="data row4 col2" >1.797810</td>
#       <td id="T_beba4_row4_col3" class="data row4 col3" >25421004.843735</td>
#       <td id="T_beba4_row4_col4" class="data row4 col4" >0.652802</td>
#       <td id="T_beba4_row4_col5" class="data row4 col5" >51.427701</td>
#     </tr>
#     <tr>
#       <th id="T_beba4_level0_row5" class="row_heading level0 row5" >LGBMTunedTest</th>
#       <td id="T_beba4_row5_col0" class="data row5 col0" >5274786586876454.000000</td>
#       <td id="T_beba4_row5_col1" class="data row5 col1" >72627726.020277</td>
#       <td id="T_beba4_row5_col2" class="data row5 col2" >1.953873</td>
#       <td id="T_beba4_row5_col3" class="data row5 col3" >26712648.187854</td>
#       <td id="T_beba4_row5_col4" class="data row5 col4" >0.691788</td>
#       <td id="T_beba4_row5_col5" class="data row5 col5" >53.317938</td>
#     </tr>
#     <tr>
#       <th id="T_beba4_level0_row6" class="row_heading level0 row6" >LGBMCVTest</th>
#       <td id="T_beba4_row6_col0" class="data row6 col0" >5169578278831617.000000</td>
#       <td id="T_beba4_row6_col1" class="data row6 col1" >71899779.407392</td>
#       <td id="T_beba4_row6_col2" class="data row6 col2" >1.941797</td>
#       <td id="T_beba4_row6_col3" class="data row6 col3" >26811477.259353</td>
#       <td id="T_beba4_row6_col4" class="data row6 col4" >0.697935</td>
#       <td id="T_beba4_row6_col5" class="data row6 col5" >53.515199</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - MAE на кросс валидации немного хуже, чем без нее, но эта разница совсем небольшая
# - остальные же метрики с кросс валидацией улучшились
# - то есть можно прийти к выводу, что модель работает довольно стабильно
# - сохраним лучшую модель в файл

# %%
joblib.dump(lgbm_optuna, 'models/lgbm_model.joblib')
# Out:
# ['models/lgbm_model.joblib']

# %% [markdown]
# - сохраним полученный датасет с метриками в тот же файл

# %%
metrics.to_csv('metrics/metrics.csv', index=False)
